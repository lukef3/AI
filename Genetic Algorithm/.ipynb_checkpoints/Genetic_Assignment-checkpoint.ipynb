# %% [markdown]
# # Genetic Algorithm Assignment
#
# ## Image Upscaling

# %% [markdown]
# ## The Problem         **(~30%)**
#
# *   Description of the problem
#
# My chosen problem for this assignment is the problem of generating a high resolution image from a single, low resolution input image. The challenge of image upscaling lies in adding the missing details in a realistic and visually appealing way. This project explores using a Genetic Algorithm to tackle this problem.
#
# *   Discussion of the suitablity of Genetic Algorithms
#
# A Genetic Algorithm is suitable here as it's a search heuristic capable of exploring a vast solution space (all possible combinations of unknown pixel values). Each potential HR image is treated as an "individual" in the GA population.
#
# The representation (chromosome) for an individual is the NumPy array holding the pixel data of the (H*2) x (W*2) candidate image. The initial population starts with the unknown pixels filled with the median value of the original image, providing a simple, neutral starting point while preserving the known original pixels. The GA then iteratively refines this population through selection, crossover, and mutation, guided by a cost function, to find images that are progressively better solutions to the upscaling problem.
#
# *   Complexity of the problem  (Overall marks allocated based on ..)

# %% [markdown]
# ## The problem and the cost function   **(~20%)**
#
# Evaluating the "quality" of a candidate HR image is crucial for the GA's success. Since the ground truth HR image is unknown, an indirect evaluation method is needed. This project primarily relies on the principle of downscaling consistency. The idea is that if a candidate HR image is genuinely a good upscale, then downscaling it back to the original LR dimensions should result in an image very similar to the original LR input.
#
# ### Initial Cost Function
#
# - Take the generated high resolution image as a numpy array (upscaled_image_array).
# - Downscale it back to the original image size using bicubic interpolation with the pillow library. This is a standard downscaling method that takes a 4x4 grid of pixels and estimates a single downscaled pixel.
# - For the cost, the mean squared error is calculated between the pixel values of this downscaled image and the original low resolution image. A lower MSE cost indicates that the upscaled image is more consistent with the original, and therefore a better upscaled image.
#
#
# ### Challenges
# - A big challenge this cost function presents is that multiple different high resolution pixel patterns could potentially average out to the same result when downscaled with bicubic interpolation. This results in images that achieve a low MSE cost, but still contain a large amount of noisy/unnatural looking pixels.
#
# ### Alternative Cost Functions Explored
# - Multiple downscales MSE: By using multiple different downscaling methods - bicubic, bilinear, nearest neighbour, and calculating the average MSE, this minimises the likelihood of "noisy" pixels being introduced and still achieving a low cost. While this does decrease the speed at which the cost improves, it does result in visual improvement.

# %%
import numpy as np
from copy import deepcopy
from PIL import Image
from IPython.display import display, clear_output
import random

# %%
# MSE of original image array vs downscaled version of upscaled image
def bicubic_downscaled_mse(upscaled_image_array, original_image_array):
    pillow_image = Image.fromarray(upscaled_image_array)
    # Resize it back to the original size using bicubic interpolation
    downscaled = pillow_image.resize((original_image_array.shape[1], original_image_array.shape[0]), Image.BICUBIC)
    # convert back to array so that MSE can be calculated
    downscaled = np.array(downscaled)

    # calculate mean squared error between original image array and the downscaled version of the upscaled image array
    mse = np.square(np.subtract(original_image_array.astype(float), downscaled.astype(float))).mean()
    return mse

# %%
# Cost function
def downscale_bicubic(upscaled_image_array, original_image_array):
    pillow_image = Image.fromarray(upscaled_image_array)
    downscaled = pillow_image.resize((original_image_array.shape[1], original_image_array.shape[0]), Image.BICUBIC)
    return np.array(downscaled)

def downscale_bilinear(upscaled_image_array, original_image_array):
    pillow_image = Image.fromarray(upscaled_image_array)
    downscaled = pillow_image.resize((original_image_array.shape[1], original_image_array.shape[0]), Image.BILINEAR)
    return np.array(downscaled)

def downscale_nearest_neighbour(upscaled_image_array, original_image_array):
    pillow_image = Image.fromarray(upscaled_image_array)
    downscaled = pillow_image.resize((original_image_array.shape[1], original_image_array.shape[0]), Image.NEAREST)
    return np.array(downscaled)

def multi_downscaled_mse(upscaled_image_array, original_image_array):
    downscaled_bicubic = downscale_bicubic(upscaled_image_array, original_image_array)
    downscaled_bilinear = downscale_bilinear(upscaled_image_array, original_image_array)
    downscaled_nearest_neighbour = downscale_nearest_neighbour(upscaled_image_array, original_image_array)

    # mean MSE of 3 downscaling methods
    cost = np.mean([
        np.square(np.subtract(original_image_array.astype(float), downscaled_bicubic.astype(float))).mean(),
        np.square(np.subtract(original_image_array.astype(float), downscaled_bilinear.astype(float))).mean(),
        np.square(np.subtract(original_image_array.astype(float), downscaled_nearest_neighbour.astype(float))).mean()
    ])

    return cost

# %%
def bicubic_downscaled_mse_with_pixel_variation(upscaled_image_array, original_image_array):
    # Ensure floating point for calculations
    img_float = upscaled_image_array.astype(np.float64)

    diff_x = np.mean(np.abs(img_float[:, 1:, :] - img_float[:, :-1, :])) # Simple diff
    diff_y = np.mean(np.abs(img_float[1:, :, :] - img_float[:-1, :, :])) # Simple diff

    # total variance between original pixels and inserted pixels
    variance = diff_x + diff_y

    downscaled_bicubic = downscale_bicubic(upscaled_image_array, original_image_array)
    mse = np.square(np.subtract(original_image_array.astype(float), downscaled_bicubic.astype(float))).mean()

    mse = mse * variance
    return mse

# %%
class problem:
    def __init__(self, original_image_array, cost_fn = bicubic_downscaled_mse):
        self.original_image_array = original_image_array
        self.min_value = 0
        self.max_value = 255
        self.acceptable_cost = 10.0
        self.cost_function = cost_fn

# %%
def upscale_image(image_array, scale_factor=2):
    original_height, original_width = image_array.shape[:2]
    new_height = original_height * scale_factor
    new_width = original_width * scale_factor

    # create array of random pixel values (1-255) of upscaled image size
    # upscaled = np.random.randint( 0, 256, size=(new_height, new_width, image_array.shape[2]), dtype=np.uint8)

    # Get median pixel value of original image array
    median_pixel_value = np.median(image_array)
    # Create upscaled image array of median pixel values
    upscaled = np.full((new_height, new_width, image_array.shape[2]), median_pixel_value, dtype=np.uint8)

    # Assign every scale-factor-th pixel to the original image pixel value
    upscaled[::scale_factor, ::scale_factor] = image_array
    return upscaled

# %%
class individual:
    def __init__(self, prob, scale_factor):
        self.chromosome = upscale_image(prob.original_image_array, scale_factor)
        self.cost = prob.cost_function(self.chromosome, prob.original_image_array)

    def mutate(self, mutation_rate, mutation_range, scale_factor):
        original_pixel_mask = np.ones(self.chromosome.shape[:2], dtype=bool) # Create an array of 'true' bool values of size chromosome.
        original_pixel_mask[::scale_factor, ::scale_factor] = False # Change every scale-factor-th bool value to false (original pixels)

        # Create an array bool values of size chromosome. Random.rand to generate array values between 0 and 1 uniformly. If value < mutation rate, true. otherwise false
        mutation_mask = np.random.rand(*self.chromosome.shape[:2]) < mutation_rate

        # Combine original pixel mask and mutation mask. Where both are true, they are left true, anything else is set to false.
        mutation_mask = original_pixel_mask & mutation_mask

        # Create 2d array of mutation values of size chromosome, from -mutation range to mutation range + 1.
        # mutations = np.random.randint(-mutation_range, mutation_range + 1, self.chromosome.shape, dtype=np.int32)

        # Create 2d array of mutation values of size chromosome, NORMALLY DISTRIBUTED between -mutation range and +mutation range. convert to integer.
        mutations = np.random.normal(0, mutation_range,self.chromosome.shape).astype(np.int32)

        # Convert chromosome to integer to allow for adding mutation
        chromosome_int = self.chromosome.astype(np.int32)
        mutation_indices = np.where(mutation_mask)
        chromosome_int[mutation_indices] += mutations[mutation_indices]

        # Clip values between 0-255 and convert to uint8
        self.chromosome = np.clip(chromosome_int, 0, 255).astype(np.uint8)

    def crossover(self, parent2, explore_crossover, scale_factor):
        alpha = np.random.uniform(-explore_crossover, 1 + explore_crossover)
        child1 = deepcopy(self)
        child2 = deepcopy(parent2)

        # Same logic as mutation
        original_pixel_mask = np.ones(self.chromosome.shape[:2], dtype=bool)
        original_pixel_mask[::scale_factor, ::scale_factor] = False

        # Create child chromosomes (unmasked. original pixel values affected)
        child1chromosome = alpha * self.chromosome + (1 - alpha) * parent2.chromosome
        child2chromosome = alpha * parent2.chromosome + (1 - alpha) * self.chromosome

        # Create new chromosomes with original pixel values masked
        child1.chromosome[original_pixel_mask] = child1chromosome[original_pixel_mask]
        child2.chromosome[original_pixel_mask] = child2chromosome[original_pixel_mask]

        # Ensure values are between 0-255 and as dtype uint8
        child1.chromosome = np.clip(child1.chromosome, 0, 255).astype(np.uint8)
        child2.chromosome = np.clip(child2.chromosome, 0, 255).astype(np.uint8)

        return child1, child2

# %%
def tournament_selection(population, tournament_size=5):
    # Choose a random 'tournament_size' number  individuals from population
    tournament = random.sample(population, tournament_size)
    tournament.sort(key=lambda x: x.cost) # Order by cost ascending

    return tournament[0] # Return tournament winner, individual with the lowest cost in selection

# %%
def choose_parents(population, tournament_size=5):
    parent1 = tournament_selection(population, tournament_size)
    parent2 = tournament_selection(population, tournament_size)

    # Redo tournament if parents are the same
    while parent1 == parent2:
        parent2 = tournament_selection(population, tournament_size)

    # Return parents
    return parent1, parent2

# %%
class parameters:
    def __init__(self):
        self.upscale_factor = 2 # Number of pixels to be inserted between each original
        self.population_size = 100
        self.birth_rate_per_generation = 1
        self.rate_of_gene_mutation = 0.001 # Chance of pixel being mutated
        self.range_of_gene_mutation = 5 # Range of pixel value mutation offset
        self.explore_crossover = 0.001
        self.max_number_of_generations = 10000
        self.tournament_size = 5

# %%
def run_genetic(prob, params, image_updates = False):
    # Read variables
    population_size = params.population_size
    number_of_children = population_size * params.birth_rate_per_generation
    mutation_rate = params.rate_of_gene_mutation
    mutation_range = params.range_of_gene_mutation
    explore_crossover = params.explore_crossover
    cost_function = prob.cost_function
    acceptable_cost = prob.acceptable_cost
    scale_factor = params.upscale_factor
    tournament_size = params.tournament_size
    original_image_array = prob.original_image_array

    # Create population
    population = []
    best_solution = individual(prob, scale_factor)
    best_solution.cost = np.inf
    for i in range(population_size):
        new_individual = individual(prob, scale_factor)
        if new_individual.cost < best_solution.cost:
            best_solution = deepcopy(new_individual)
        population.append(new_individual)

    # Start loop
    for generation in range(params.max_number_of_generations):
        children = []
        while len(children) < number_of_children:
            # Choose parents
            p1, p2 = choose_parents(population, tournament_size)
            # Create children
            c1, c2 = p1.crossover(p2, explore_crossover, scale_factor)
            c1.mutate(mutation_rate, mutation_range, scale_factor)
            c2.mutate(mutation_rate, mutation_range, scale_factor)
            c1.cost = cost_function(c1.chromosome, original_image_array)
            c2.cost = cost_function(c2.chromosome, original_image_array)
            children.append(c1)
            children.append(c2)

        population += children

        # Sort population
        population.sort(key=lambda x: x.cost)

        # Cull population
        population = population[:population_size]

        # Check solution
        if population[0].cost < best_solution.cost:
            # save new best solution
            best_solution = deepcopy(population[0])
            if (image_updates):
                # Display new best image
                # clear output for live image progress
                clear_output(wait=True)
                print(f"Generation {generation+1}: Best cost: {best_solution.cost}")
                best_img = Image.fromarray(best_solution.chromosome)
                display(best_img)
            if not (image_updates):
                print(f"Generation {generation+1}: Best cost: {best_solution.cost}")
        if best_solution.cost < acceptable_cost:
            print("Accpetable cost reached")
            break

    return population, best_solution, best_solution.cost

# %%
def load_image(path):
    # Convert original image to numpy array
    img = Image.open(path).convert("RGB")  # For color images
    return np.array(img)

# %%
# Test
image_path = "img1.png"
original_image_array = load_image(image_path)

upscaled_image_array = upscale_image(original_image_array, 2)
downscaled_bilinear_array = downscale_bilinear(upscaled_image_array, original_image_array)
downscaled_bicubic_array = downscale_bicubic(upscaled_image_array, original_image_array)
downscaled_nearest_neighbour = downscale_nearest_neighbour(downscaled_bilinear_array, original_image_array)

original = Image.fromarray(original_image_array)
up = Image.fromarray(upscaled_image_array)
downscaled_bicubic = Image.fromarray(downscaled_bicubic_array)
downscaled_bilinear = Image.fromarray(downscaled_bilinear_array)
downscaled_nearest_neighbour = Image.fromarray(downscaled_nearest_neighbour)
display(original)
display(up)
display(downscaled_bicubic)
display(downscaled_bilinear)
display(downscaled_nearest_neighbour)
# Out:
# <PIL.Image.Image image mode=RGB size=50x50>
# <PIL.Image.Image image mode=RGB size=100x100>
# <PIL.Image.Image image mode=RGB size=50x50>
# <PIL.Image.Image image mode=RGB size=50x50>
# <PIL.Image.Image image mode=RGB size=50x50>

# %%
image_path = "img1.png"
original_image_array = load_image(image_path)

# Create problem and set parameters
params = parameters()
params.upscale_factor = 2
params.population_size = 100
params.birth_rate_per_generation = 1
params.rate_of_gene_mutation = 0.005
params.range_of_gene_mutation = 20
params.explore_crossover = 0.1
params.max_number_of_generations = 20000
params.tournament_size = 10

prob = problem(original_image_array, bicubic_downscaled_mse)
prob.acceptable_cost = 433

# Run genetic algorithm
pop, best, best_cost = run_genetic(prob, params, False)
best_img = Image.fromarray(best.chromosome)
print("Final best cost:", best_cost)
print("Final best image:")
display(best_img)

# %%
image_path = "img1.png"
original_image_array = load_image(image_path)

# Create problem and set parameters
params = parameters()
params.upscale_factor = 2
params.population_size = 100
params.birth_rate_per_generation = 1
params.rate_of_gene_mutation = 0.01
params.range_of_gene_mutation = 15
params.explore_crossover = 0.1
params.max_number_of_generations = 2000
params.tournament_size = 7

prob = problem(original_image_array, multi_downscaled_mse)

# Run genetic algorithm
pop, best, best_cost = run_genetic(prob, params, False)
best_img = Image.fromarray(best.chromosome)
print("Final best cost:", best_cost)
print("Final best image:")
display(best_img)
# Out:
# Generation 1: Best cost: 1936.1402222222223
# Generation 2: Best cost: 1935.1866222222222
# Generation 3: Best cost: 1934.6588444444444
# Generation 4: Best cost: 1933.6348
# Generation 5: Best cost: 1932.8652000000002
# Generation 6: Best cost: 1932.3766666666668
# Generation 7: Best cost: 1932.027911111111
# Generation 8: Best cost: 1931.602622222222
# Generation 9: Best cost: 1931.2078222222224
# Generation 10: Best cost: 1930.6671999999999
# Generation 11: Best cost: 1929.9118666666666
# Generation 12: Best cost: 1929.6693333333333
# Generation 13: Best cost: 1929.6056888888888
# Generation 14: Best cost: 1929.0725777777777
# Generation 15: Best cost: 1928.8736444444446
# Generation 16: Best cost: 1928.0976444444448
# Generation 19: Best cost: 1927.9594666666665
# Generation 20: Best cost: 1927.7704444444444
# Generation 23: Best cost: 1927.093911111111
# Generation 25: Best cost: 1927.003777777778
# Generation 26: Best cost: 1926.891555555556
# Generation 27: Best cost: 1926.2224888888888
# Generation 31: Best cost: 1925.9329333333335
# Generation 32: Best cost: 1925.5226666666665
# Generation 33: Best cost: 1925.2969333333333
# Generation 38: Best cost: 1924.9564
# Generation 39: Best cost: 1924.7682666666667
# Generation 40: Best cost: 1924.6477777777775
# Generation 43: Best cost: 1924.0533333333333
# Generation 48: Best cost: 1923.271911111111
# Generation 49: Best cost: 1922.2322222222222
# Generation 55: Best cost: 1921.604177777778
# Generation 56: Best cost: 1921.556888888889
# Generation 57: Best cost: 1921.333288888889
# Generation 59: Best cost: 1920.4194666666665
# Generation 60: Best cost: 1920.271066666667
# Generation 61: Best cost: 1920.0104444444448
# Generation 62: Best cost: 1919.5514666666666
# Generation 63: Best cost: 1919.0770222222225
# Generation 64: Best cost: 1917.9730222222224
# Generation 67: Best cost: 1917.4708444444443
# Generation 69: Best cost: 1916.822488888889
# Generation 71: Best cost: 1916.149911111111
# Generation 73: Best cost: 1915.6900888888888
# Generation 75: Best cost: 1915.2607555555558
# Generation 76: Best cost: 1914.8243111111112
# Generation 78: Best cost: 1914.536311111111
# Generation 81: Best cost: 1914.3179555555555
# Generation 83: Best cost: 1914.21
# Generation 85: Best cost: 1914.0493777777776
# Generation 86: Best cost: 1913.5346666666665
# Generation 87: Best cost: 1913.4796444444446
# Generation 88: Best cost: 1912.9557333333332
# Generation 97: Best cost: 1912.8228444444446
# Generation 98: Best cost: 1912.8102666666666
# Generation 101: Best cost: 1912.4618222222223
# Generation 103: Best cost: 1912.2143111111109
# Generation 104: Best cost: 1911.9594666666665
# Generation 106: Best cost: 1911.8820888888888
# Generation 107: Best cost: 1911.6213333333333
# Generation 108: Best cost: 1911.5324
# Generation 114: Best cost: 1911.3921333333335
# Generation 121: Best cost: 1910.325911111111
# Generation 130: Best cost: 1909.7846666666665
# Generation 132: Best cost: 1909.557911111111
# Generation 133: Best cost: 1908.9326666666666
# Generation 134: Best cost: 1908.0330666666669
# Generation 137: Best cost: 1907.783111111111
# Generation 138: Best cost: 1907.301777777778
# Generation 139: Best cost: 1906.8792
# Generation 140: Best cost: 1906.4617333333335
# Generation 142: Best cost: 1905.8064444444444
# Generation 144: Best cost: 1905.5584888888889
# Generation 146: Best cost: 1904.7193333333332
# Generation 148: Best cost: 1904.6110222222221
# Generation 149: Best cost: 1904.0986222222225
# Generation 151: Best cost: 1903.8386222222223
# Generation 153: Best cost: 1902.9241333333332
# Generation 154: Best cost: 1902.9240444444447
# Generation 155: Best cost: 1902.431111111111
# Generation 163: Best cost: 1901.5094666666664
# Generation 170: Best cost: 1901.415511111111
# Generation 171: Best cost: 1901.0473777777777
# Generation 175: Best cost: 1899.7051999999996
# Generation 179: Best cost: 1898.8376
# Generation 183: Best cost: 1897.7615999999998
# Generation 184: Best cost: 1897.7392444444442
# Generation 186: Best cost: 1896.9980888888888
# Generation 190: Best cost: 1896.9751111111111
# Generation 191: Best cost: 1896.6265777777778
# Generation 192: Best cost: 1896.3549777777778
# Generation 197: Best cost: 1895.8782666666666
# Generation 199: Best cost: 1895.0952444444447
# Generation 206: Best cost: 1894.5419111111112
# Generation 207: Best cost: 1894.5310666666664
# Generation 208: Best cost: 1893.5461333333333
# Generation 212: Best cost: 1893.5331555555556
# Generation 213: Best cost: 1893.240044444444
# Generation 215: Best cost: 1892.707333333333
# Generation 218: Best cost: 1892.5235999999998
# Generation 222: Best cost: 1891.3841777777777
# Generation 226: Best cost: 1890.8700888888889
# Generation 227: Best cost: 1890.2312444444444
# Generation 230: Best cost: 1889.9546222222223
# Generation 231: Best cost: 1889.6527999999998
# Generation 233: Best cost: 1889.5564444444444
# Generation 234: Best cost: 1889.2226222222223
# Generation 236: Best cost: 1888.850888888889
# Generation 239: Best cost: 1888.6956444444447
# Generation 247: Best cost: 1888.2588444444445
# Generation 248: Best cost: 1888.070088888889
# Generation 249: Best cost: 1887.3983555555558
# Generation 255: Best cost: 1887.276711111111
# Generation 256: Best cost: 1887.0044888888888
# Generation 257: Best cost: 1886.9344444444444
# Generation 260: Best cost: 1886.6481777777778
# Generation 265: Best cost: 1886.5608888888892
# Generation 267: Best cost: 1886.4052444444442
# Generation 271: Best cost: 1886.2528444444445
# Generation 274: Best cost: 1886.1969333333334
# Generation 276: Best cost: 1885.4369333333334
# Generation 277: Best cost: 1884.5855555555554
# Generation 279: Best cost: 1884.0319555555554
# Generation 281: Best cost: 1883.9784444444442
# Generation 282: Best cost: 1883.4500444444445
# Generation 283: Best cost: 1883.3323111111113
# Generation 284: Best cost: 1883.2251555555558
# Generation 285: Best cost: 1882.2420000000002
# Generation 288: Best cost: 1881.4016444444444
# Generation 290: Best cost: 1881.372888888889
# Generation 291: Best cost: 1880.9332888888891
# Generation 293: Best cost: 1880.6035111111112
# Generation 294: Best cost: 1880.222088888889
# Generation 299: Best cost: 1880.1431555555555
# Generation 300: Best cost: 1880.055511111111
# Generation 301: Best cost: 1879.5266222222224
# Generation 304: Best cost: 1878.3275999999998
# Generation 310: Best cost: 1877.5664444444446
# Generation 312: Best cost: 1877.4626666666666
# Generation 314: Best cost: 1877.4336444444446
# Generation 316: Best cost: 1875.475688888889
# Generation 321: Best cost: 1875.2592888888887
# Generation 322: Best cost: 1875.1645333333333
# Generation 323: Best cost: 1874.304
# Generation 325: Best cost: 1873.0959111111108
# Generation 326: Best cost: 1872.4701333333335
# Generation 328: Best cost: 1872.4020444444443
# Generation 330: Best cost: 1872.4000444444446
# Generation 332: Best cost: 1871.7445777777775
# Generation 333: Best cost: 1871.5686222222223
# Generation 335: Best cost: 1870.960711111111
# Generation 338: Best cost: 1870.5846666666669
# Generation 339: Best cost: 1870.5072
# Generation 340: Best cost: 1870.0758666666668
# Generation 342: Best cost: 1870.014577777778
# Generation 343: Best cost: 1869.9360444444446
# Generation 344: Best cost: 1869.4887555555554
# Generation 346: Best cost: 1869.4513777777775
# Generation 347: Best cost: 1868.6396888888892
# Generation 349: Best cost: 1867.9149333333335
# Generation 353: Best cost: 1867.8991999999998
# Generation 357: Best cost: 1866.8945333333334
# Generation 364: Best cost: 1866.6132
# Generation 365: Best cost: 1866.4389333333331
# Generation 367: Best cost: 1866.111377777778
# Generation 370: Best cost: 1865.902711111111
# Generation 371: Best cost: 1865.3952
# Generation 380: Best cost: 1864.6972444444446
# Generation 392: Best cost: 1863.3427999999997
# Generation 399: Best cost: 1862.7012444444445
# Generation 401: Best cost: 1862.5218666666667
# Generation 403: Best cost: 1861.7541333333331
# Generation 406: Best cost: 1861.6606666666667
# Generation 407: Best cost: 1861.468311111111
# Generation 412: Best cost: 1861.2733777777776
# Generation 418: Best cost: 1860.6921777777777
# Generation 440: Best cost: 1860.6102666666666
# Generation 443: Best cost: 1860.5584888888889
# Generation 447: Best cost: 1860.4621333333332
# Generation 448: Best cost: 1860.1717333333333
# Generation 451: Best cost: 1859.8826666666666
# Generation 460: Best cost: 1859.8330666666668
# Generation 462: Best cost: 1859.7232000000001
# Generation 464: Best cost: 1859.2964444444442
# Generation 465: Best cost: 1859.1990222222223
# Generation 466: Best cost: 1857.8043555555557
# Generation 469: Best cost: 1857.624488888889
# Generation 472: Best cost: 1857.1632
# Generation 474: Best cost: 1857.1346666666668
# Generation 476: Best cost: 1857.052977777778
# Generation 477: Best cost: 1856.1943555555554
# Generation 479: Best cost: 1855.861288888889
# Generation 483: Best cost: 1853.4904888888889
# Generation 492: Best cost: 1853.2248
# Generation 495: Best cost: 1853.1791111111113
# Generation 496: Best cost: 1853.0150222222221
# Generation 498: Best cost: 1852.7618666666667
# Generation 500: Best cost: 1851.5829777777778
# Generation 505: Best cost: 1851.0397333333333
# Generation 511: Best cost: 1850.8030222222224
# Generation 513: Best cost: 1849.1747555555557
# Generation 518: Best cost: 1848.9882666666665
# Generation 519: Best cost: 1848.4457333333332
# Generation 522: Best cost: 1848.4368000000002
# Generation 523: Best cost: 1848.0509777777777
# Generation 525: Best cost: 1847.7516444444445
# Generation 526: Best cost: 1847.7277333333332
# Generation 527: Best cost: 1847.4347555555553
# Generation 528: Best cost: 1847.3287555555555
# Generation 540: Best cost: 1847.1032888888888
# Generation 541: Best cost: 1846.2164444444443
# Generation 548: Best cost: 1846.0732
# Generation 550: Best cost: 1845.9909333333335
# Generation 551: Best cost: 1845.8587555555557
# Generation 552: Best cost: 1845.5193333333334
# Generation 556: Best cost: 1845.3112
# Generation 559: Best cost: 1845.1704000000002
# Generation 561: Best cost: 1844.9264444444445
# Generation 574: Best cost: 1844.868311111111
# Generation 575: Best cost: 1844.3049777777778
# Generation 582: Best cost: 1843.7800888888887
# Generation 583: Best cost: 1842.6008000000002
# Generation 586: Best cost: 1842.4376
# Generation 587: Best cost: 1842.068177777778
# Generation 591: Best cost: 1841.9046666666666
# Generation 592: Best cost: 1841.5149777777779
# Generation 605: Best cost: 1841.1440444444445
# Generation 613: Best cost: 1840.558266666667
# Generation 635: Best cost: 1840.5447111111114
# Generation 640: Best cost: 1839.845022222222
# Generation 645: Best cost: 1839.4133333333332
# Generation 647: Best cost: 1839.1224000000002
# Generation 648: Best cost: 1839.033733333333
# Generation 650: Best cost: 1838.8778222222224
# Generation 652: Best cost: 1838.722
# Generation 655: Best cost: 1837.6188
# Generation 658: Best cost: 1837.5644444444442
# Generation 660: Best cost: 1837.1217777777777
# Generation 668: Best cost: 1836.615288888889
# Generation 670: Best cost: 1836.5050666666666
# Generation 672: Best cost: 1836.2695555555554
# Generation 675: Best cost: 1835.7970222222223
# Generation 676: Best cost: 1835.5218666666667
# Generation 679: Best cost: 1834.8712000000003
# Generation 681: Best cost: 1834.796711111111
# Generation 684: Best cost: 1834.4760888888889
# Generation 693: Best cost: 1834.4385333333332
# Generation 702: Best cost: 1834.1697333333334
# Generation 703: Best cost: 1833.8881777777779
# Generation 705: Best cost: 1833.8786222222225
# Generation 717: Best cost: 1833.7469333333331
# Generation 719: Best cost: 1833.1865777777778
# Generation 720: Best cost: 1833.0072
# Generation 721: Best cost: 1832.8656444444443
# Generation 722: Best cost: 1832.5022666666664
# Generation 723: Best cost: 1830.7591555555555
# Generation 725: Best cost: 1830.5434666666667
# Generation 727: Best cost: 1829.9314222222222
# Generation 729: Best cost: 1828.9815999999998
# Generation 735: Best cost: 1828.5849777777778
# Generation 740: Best cost: 1828.4108444444446
# Generation 741: Best cost: 1828.2483999999997
# Generation 742: Best cost: 1827.5447555555554
# Generation 744: Best cost: 1827.417511111111
# Generation 746: Best cost: 1827.4107555555556
# Generation 757: Best cost: 1827.3287555555555
# Generation 759: Best cost: 1827.228577777778
# Generation 762: Best cost: 1827.0835555555557
# Generation 764: Best cost: 1827.0211555555554
# Generation 767: Best cost: 1826.7723999999998
# Generation 769: Best cost: 1826.062222222222
# Generation 779: Best cost: 1825.323511111111
# Generation 787: Best cost: 1825.2258666666667
# Generation 788: Best cost: 1824.6942666666666
# Generation 790: Best cost: 1824.6773333333333
# Generation 792: Best cost: 1823.9889333333333
# Generation 794: Best cost: 1823.5955999999999
# Generation 800: Best cost: 1823.4883111111112
# Generation 802: Best cost: 1822.7530666666664
# Generation 808: Best cost: 1822.636888888889
# Generation 816: Best cost: 1822.1253333333334
# Generation 818: Best cost: 1821.984711111111
# Generation 828: Best cost: 1821.936088888889
# Generation 834: Best cost: 1821.4290666666666
# Generation 835: Best cost: 1821.3346222222224
# Generation 837: Best cost: 1821.1887111111112
# Generation 841: Best cost: 1820.978933333333
# Generation 842: Best cost: 1820.8265777777779
# Generation 843: Best cost: 1820.3262222222222
# Generation 847: Best cost: 1820.3050666666666
# Generation 852: Best cost: 1820.1382222222226
# Generation 853: Best cost: 1820.069422222222
# Generation 857: Best cost: 1819.8610666666666
# Generation 858: Best cost: 1819.6680888888889
# Generation 860: Best cost: 1819.1425333333334
# Generation 861: Best cost: 1818.5959111111113
# Generation 876: Best cost: 1818.5107555555558
# Generation 899: Best cost: 1818.1140000000003
# Generation 904: Best cost: 1817.603688888889
# Generation 905: Best cost: 1817.5365333333332
# Generation 906: Best cost: 1817.3995555555557
# Generation 908: Best cost: 1817.0960000000002
# Generation 909: Best cost: 1816.5792444444444
# Generation 910: Best cost: 1815.8062222222222
# Generation 913: Best cost: 1815.4761777777778
# Generation 914: Best cost: 1814.9304
# Generation 918: Best cost: 1814.7704888888886
# Generation 919: Best cost: 1814.692711111111
# Generation 920: Best cost: 1814.5165777777777
# Generation 922: Best cost: 1813.9543555555556
# Generation 927: Best cost: 1813.0181333333333
# Generation 944: Best cost: 1813.0171555555553
# Generation 945: Best cost: 1812.5331999999999
# Generation 949: Best cost: 1812.3795555555555
# Generation 952: Best cost: 1812.1138666666666
# Generation 953: Best cost: 1812.0208444444445
# Generation 957: Best cost: 1811.5739111111113
# Generation 959: Best cost: 1810.9228
# Generation 960: Best cost: 1810.719688888889
# Generation 962: Best cost: 1810.632977777778
# Generation 965: Best cost: 1810.111688888889
# Generation 973: Best cost: 1810.0027111111112
# Generation 974: Best cost: 1809.2733333333333
# Generation 988: Best cost: 1809.167022222222
# Generation 991: Best cost: 1809.0355555555554
# Generation 994: Best cost: 1808.8414222222225
# Generation 995: Best cost: 1807.4383555555553
# Generation 1002: Best cost: 1807.42
# Generation 1007: Best cost: 1807.3694222222223
# Generation 1008: Best cost: 1807.3296
# Generation 1011: Best cost: 1806.9401777777778
# Generation 1012: Best cost: 1806.3015555555555
# Generation 1029: Best cost: 1806.2288888888888
# Generation 1030: Best cost: 1806.1728
# Generation 1032: Best cost: 1805.7374222222224
# Generation 1035: Best cost: 1805.6078222222222
# Generation 1036: Best cost: 1805.0722666666668
# Generation 1037: Best cost: 1804.333911111111
# Generation 1041: Best cost: 1804.078888888889
# Generation 1045: Best cost: 1803.4051555555554
# Generation 1048: Best cost: 1802.4650666666666
# Generation 1051: Best cost: 1801.888
# Generation 1053: Best cost: 1801.7351555555554
# Generation 1056: Best cost: 1801.2194222222222
# Generation 1059: Best cost: 1800.7847111111112
# Generation 1061: Best cost: 1800.3913777777777
# Generation 1066: Best cost: 1800.2391111111112
# Generation 1067: Best cost: 1799.718488888889
# Generation 1073: Best cost: 1799.3239555555556
# Generation 1074: Best cost: 1799.1022666666668
# Generation 1080: Best cost: 1798.441911111111
# Generation 1081: Best cost: 1798.4289333333334
# Generation 1084: Best cost: 1798.3971111111114
# Generation 1085: Best cost: 1798.0897333333335
# Generation 1089: Best cost: 1797.7183999999997
# Generation 1093: Best cost: 1797.1188444444444
# Generation 1101: Best cost: 1797.0913777777778
# Generation 1105: Best cost: 1796.9363555555556
# Generation 1106: Best cost: 1796.669688888889
# Generation 1110: Best cost: 1796.427511111111
# Generation 1116: Best cost: 1796.3433333333332
# Generation 1119: Best cost: 1795.4496
# Generation 1127: Best cost: 1794.949822222222
# Generation 1135: Best cost: 1794.7838222222224
# Generation 1138: Best cost: 1794.0891555555554
# Generation 1149: Best cost: 1793.3890666666666
# Generation 1151: Best cost: 1792.917422222222
# Generation 1157: Best cost: 1792.684177777778
# Generation 1159: Best cost: 1792.167022222222
# Generation 1160: Best cost: 1792.1024444444445
# Generation 1163: Best cost: 1792.0490666666665
# Generation 1164: Best cost: 1791.752577777778
# Generation 1166: Best cost: 1791.3782666666666
# Generation 1171: Best cost: 1791.1057333333335
# Generation 1172: Best cost: 1790.717111111111
# Generation 1174: Best cost: 1790.6192
# Generation 1179: Best cost: 1790.1549777777775
# Generation 1180: Best cost: 1789.8044
# Generation 1185: Best cost: 1789.5836
# Generation 1191: Best cost: 1789.3656444444448
# Generation 1193: Best cost: 1789.0341777777776
# Generation 1195: Best cost: 1788.7269333333334
# Generation 1199: Best cost: 1787.8061777777777
# Generation 1203: Best cost: 1786.5552
# Generation 1210: Best cost: 1786.0316000000003
# Generation 1211: Best cost: 1785.1747555555557
# Generation 1214: Best cost: 1785.0256000000002
# Generation 1216: Best cost: 1784.9269333333334
# Generation 1218: Best cost: 1784.8823111111112
# Generation 1219: Best cost: 1784.8784888888888
# Generation 1223: Best cost: 1784.6057777777778
# Generation 1225: Best cost: 1784.4637777777778
# Generation 1228: Best cost: 1784.2311555555555
# Generation 1238: Best cost: 1783.863511111111
# Generation 1240: Best cost: 1782.9739555555554
# Generation 1249: Best cost: 1782.8408444444442
# Generation 1250: Best cost: 1782.5331999999999
# Generation 1251: Best cost: 1782.2684444444446
# Generation 1252: Best cost: 1782.2368888888889
# Generation 1255: Best cost: 1782.2180444444446
# Generation 1259: Best cost: 1781.754311111111
# Generation 1269: Best cost: 1781.4635555555553
# Generation 1272: Best cost: 1780.9998666666663
# Generation 1273: Best cost: 1780.9890666666668
# Generation 1274: Best cost: 1780.1692444444445
# Generation 1278: Best cost: 1780.0177333333334
# Generation 1279: Best cost: 1779.3041777777778
# Generation 1286: Best cost: 1779.1091555555556
# Generation 1290: Best cost: 1779.0331999999999
# Generation 1293: Best cost: 1779.0295555555556
# Generation 1294: Best cost: 1778.343911111111
# Generation 1296: Best cost: 1777.8967555555555
# Generation 1299: Best cost: 1777.6503999999998
# Generation 1301: Best cost: 1777.3383111111114
# Generation 1303: Best cost: 1777.1013333333333
# Generation 1308: Best cost: 1776.8926666666666
# Generation 1310: Best cost: 1776.45
# Generation 1314: Best cost: 1776.3354666666667
# Generation 1317: Best cost: 1776.3056888888889
# Generation 1320: Best cost: 1776.278622222222
# Generation 1326: Best cost: 1775.7579999999998
# Generation 1335: Best cost: 1775.7239111111112
# Generation 1337: Best cost: 1775.561777777778
# Generation 1338: Best cost: 1775.4945333333333
# Generation 1339: Best cost: 1775.4693777777777
# Generation 1340: Best cost: 1774.7197777777776
# Generation 1343: Best cost: 1774.4992444444445
# Generation 1347: Best cost: 1773.587733333333
# Generation 1348: Best cost: 1773.5871555555557
# Generation 1355: Best cost: 1773.0847111111113
# Generation 1361: Best cost: 1772.4694666666667
# Generation 1365: Best cost: 1771.9156444444445
# Generation 1369: Best cost: 1771.029911111111
# Generation 1376: Best cost: 1770.9973333333335
# Generation 1379: Best cost: 1770.783422222222
# Generation 1382: Best cost: 1770.4947555555555
# Generation 1384: Best cost: 1770.4411555555555
# Generation 1389: Best cost: 1770.3783999999998
# Generation 1392: Best cost: 1770.2267555555554
# Generation 1397: Best cost: 1770.0871555555557
# Generation 1398: Best cost: 1769.8500444444444
# Generation 1401: Best cost: 1769.826
# Generation 1403: Best cost: 1769.561688888889
# Generation 1411: Best cost: 1769.1742222222222
# Generation 1412: Best cost: 1768.8933333333334
# Generation 1413: Best cost: 1768.4512888888887
# Generation 1420: Best cost: 1767.8844888888889
# Generation 1426: Best cost: 1767.6644444444446
# Generation 1431: Best cost: 1766.9832888888886
# Generation 1437: Best cost: 1766.923511111111
# Generation 1438: Best cost: 1766.8241777777778
# Generation 1439: Best cost: 1766.4946222222222
# Generation 1441: Best cost: 1766.1701333333333
# Generation 1448: Best cost: 1765.8120888888889
# Generation 1458: Best cost: 1765.590622222222
# Generation 1460: Best cost: 1764.913822222222
# Generation 1465: Best cost: 1764.4447555555555
# Generation 1472: Best cost: 1763.0212
# Generation 1478: Best cost: 1762.4397777777779
# Generation 1481: Best cost: 1761.5369777777778
# Generation 1506: Best cost: 1761.2748888888889
# Generation 1508: Best cost: 1761.0268444444446
# Generation 1512: Best cost: 1760.846488888889
# Generation 1513: Best cost: 1760.6599111111111
# Generation 1519: Best cost: 1760.6162666666667
# Generation 1522: Best cost: 1760.3325333333335
# Generation 1524: Best cost: 1760.311511111111
# Generation 1528: Best cost: 1760.0234222222225
# Generation 1531: Best cost: 1759.782577777778
# Generation 1532: Best cost: 1759.6663555555558
# Generation 1534: Best cost: 1759.0228
# Generation 1545: Best cost: 1758.9344444444444
# Generation 1547: Best cost: 1758.827422222222
# Generation 1551: Best cost: 1758.4855555555557
# Generation 1570: Best cost: 1758.4479111111111
# Generation 1572: Best cost: 1758.1856888888888
# Generation 1575: Best cost: 1757.9892
# Generation 1581: Best cost: 1757.8968000000002
# Generation 1582: Best cost: 1757.645688888889
# Generation 1583: Best cost: 1757.2726666666665
# Generation 1584: Best cost: 1756.9963111111113
# Generation 1585: Best cost: 1756.7447555555555
# Generation 1591: Best cost: 1756.1111111111113
# Generation 1597: Best cost: 1755.8787999999997
# Generation 1598: Best cost: 1755.6768
# Generation 1600: Best cost: 1755.5576444444443
# Generation 1602: Best cost: 1755.0465333333334
# Generation 1604: Best cost: 1753.4186666666665
# Generation 1617: Best cost: 1753.0471555555553
# Generation 1621: Best cost: 1752.938666666667
# Generation 1622: Best cost: 1751.7254666666668
# Generation 1628: Best cost: 1751.6192888888888
# Generation 1633: Best cost: 1750.9879111111113
# Generation 1634: Best cost: 1750.9689333333336
# Generation 1636: Best cost: 1750.9194222222222
# Generation 1639: Best cost: 1750.8379555555555
# Generation 1641: Best cost: 1750.0815555555555
# Generation 1644: Best cost: 1749.6714222222224
# Generation 1649: Best cost: 1748.800888888889
# Generation 1651: Best cost: 1748.0984888888888
# Generation 1652: Best cost: 1748.0107555555558
# Generation 1655: Best cost: 1747.3981333333334
# Generation 1657: Best cost: 1746.4521333333334
# Generation 1660: Best cost: 1746.1275555555555
# Generation 1663: Best cost: 1745.864888888889
# Generation 1668: Best cost: 1745.7274222222222
# Generation 1671: Best cost: 1745.6423555555557
# Generation 1672: Best cost: 1745.1146222222221
# Generation 1677: Best cost: 1744.4614666666669
# Generation 1680: Best cost: 1744.4573333333335
# Generation 1686: Best cost: 1744.455777777778
# Generation 1687: Best cost: 1744.3783111111109
# Generation 1690: Best cost: 1744.2838222222224
# Generation 1691: Best cost: 1744.2334666666666
# Generation 1696: Best cost: 1743.923511111111
# Generation 1699: Best cost: 1743.6767111111112
# Generation 1702: Best cost: 1741.9776000000002
# Generation 1705: Best cost: 1741.6916888888888
# Generation 1707: Best cost: 1741.4993333333332
# Generation 1708: Best cost: 1741.4930222222222
# Generation 1711: Best cost: 1740.921288888889
# Generation 1714: Best cost: 1740.6431111111112
# Generation 1722: Best cost: 1740.0608444444442
# Generation 1723: Best cost: 1739.351111111111
# Generation 1727: Best cost: 1739.2451555555556
# Generation 1734: Best cost: 1738.9060444444447
# Generation 1736: Best cost: 1738.6633333333332
# Generation 1738: Best cost: 1738.5164000000002
# Generation 1741: Best cost: 1738.0449777777776
# Generation 1742: Best cost: 1737.903111111111
# Generation 1745: Best cost: 1737.7011111111112
# Generation 1750: Best cost: 1736.6635555555556
# Generation 1764: Best cost: 1735.9998666666668
# Generation 1779: Best cost: 1735.5653777777777
# Generation 1786: Best cost: 1735.479511111111
# Generation 1787: Best cost: 1735.3064000000002
# Generation 1790: Best cost: 1735.0553333333335
# Generation 1791: Best cost: 1734.912
# Generation 1793: Best cost: 1734.1858666666667
# Generation 1807: Best cost: 1733.9745777777778
# Generation 1812: Best cost: 1733.6639555555557
# Generation 1818: Best cost: 1733.5346666666667
# Generation 1819: Best cost: 1732.948088888889
# Generation 1821: Best cost: 1732.6092
# Generation 1829: Best cost: 1732.3678222222225
# Generation 1832: Best cost: 1731.7944444444445
# Generation 1833: Best cost: 1731.7025333333331
# Generation 1841: Best cost: 1731.6511555555555
# Generation 1842: Best cost: 1731.3924
# Generation 1847: Best cost: 1731.2392444444442
# Generation 1852: Best cost: 1731.0192444444444
# Generation 1861: Best cost: 1730.8978666666665
# Generation 1862: Best cost: 1730.7160444444446
# Generation 1863: Best cost: 1730.1708444444446
# Generation 1875: Best cost: 1730.0531555555556
# Generation 1885: Best cost: 1729.9464444444445
# Generation 1890: Best cost: 1729.912
# Generation 1891: Best cost: 1729.5836888888891
# Generation 1895: Best cost: 1729.025111111111
# Generation 1896: Best cost: 1729.017288888889
# Generation 1898: Best cost: 1728.3069333333333
# Generation 1913: Best cost: 1728.0919555555556
# Generation 1918: Best cost: 1727.3899555555556
# Generation 1934: Best cost: 1726.798133333333
# Generation 1940: Best cost: 1726.6243555555557
# Generation 1941: Best cost: 1726.6234222222222
# Generation 1942: Best cost: 1725.7092
# Generation 1948: Best cost: 1725.3765777777778
# Generation 1952: Best cost: 1725.2578222222226
# Generation 1954: Best cost: 1724.8343555555555
# Generation 1962: Best cost: 1724.695333333333
# Generation 1967: Best cost: 1724.2336444444445
# Generation 1970: Best cost: 1723.6130222222225
# Generation 1974: Best cost: 1723.4188444444444
# Generation 1975: Best cost: 1723.2854222222225
# Generation 1977: Best cost: 1722.9816
# Generation 1978: Best cost: 1721.9177333333334
# Generation 1985: Best cost: 1721.779111111111
# Generation 1987: Best cost: 1721.2290666666668
# Generation 2000: Best cost: 1721.1408
# Final best cost: 1721.1408
# Final best image:
# <PIL.Image.Image image mode=RGB size=100x100>
